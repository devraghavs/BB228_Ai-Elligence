# %%
import requests
import json
import time
# Python program to read 
# json file  
f = open('ALL_Train_Schedule.json',) 
  
# returns JSON object as  
# a dictionary 
trn_sch = json.load(f)

# %%
exception=['06549','02233','05956','08494','06504','05955','09090','06795','02091','06503','02793','02794','06550','01139','08493','02092','04010','09084','04009','09089','03112','02089','08491','02090','01140','09083','04739','04740','02234','06796','02414']
x=['02904', '02618', '02432', '02414', '02926', '20926', '02952', '02284']
print(set(x)-set(exception))
#trn_sch={'02952': [['NDLS', 'Null', '17:00'], ['KOTA', '21:40', '21:50'], ['RTM', '00:42', '00:45'], ['BRC', '03:48', '03:56'], ['ST', '05:28', '05:33'], ['BCT', '08:40', 'Null']], '02904': [['NDLS', 'Null', '07:20'], ['FDB', '07:37', '07:39'], ['MTJ', '09:45', '09:50'], ['BTE', '10:23', '10:25'], ['BXN', '10:53', '10:55'], ['HAN', '11:18', '11:20'], ['SMBJ', '11:28', '11:30'], ['GGC', '12:00', '12:05'], ['SWM', '12:50', '12:55'], ['KOTA', '14:15', '14:25'], ['RMA', '15:21', '15:22'], ['BWM', '15:43', '15:45'], ['SGZ', '16: 08', '16: 10'], ['NAD', '17:50', '17:52'], ['RTM', '18:50', '19:00'], ['MGN', '20:03', '20:05'], ['DHD', '20: 3220: 34'], ['GDA', '21: 51', '21: 53'], ['BRC', '22: 53', '23: 03'], ['ST', '00: 57', '01: 02'], ['BVI', '03: 58', '04: 02'], ['DDR', '04:41', '04:44'], ['BCT', '05:05', 'Null']], '02414': [['NDLS', 'Null', '11:25'], ['KOTA', '16:00', '16:10'], ['BRC', '22:50', '23:08'], ['ST', '00:43', '00:46'], ['PNVL', '05:08', '05:13'], ['RN', '09:30', '09:35'], ['MAO', '12:50', 'Null']], '02618': [['NDLS', 'Null', '09:15'], ['FDB', '09: 35', '09: 37'], ['MTJ', '11: 03', '11: 05'], ['AGC', '11: 50', '11: 55'], ['MRA', '13: 22', '13: 24'], ['GWL', '13: 55', '14: 00'], ['JHS', '15: 30', '15: 40'], ['BINA', '17: 40', '17: 45'], ['BPL', '19:40', '19:50'], ['ET', '21:25', '21:30'], ['KNW', '23;37', '23:40'], ['BAU', '00:30', '00:32'], ['BSL', '01:30', '01:35'], ['MMR', '04: 23', '04: 25'], ['NK', '\t05: 15', '05: 20'], ['IGP', '06: 40', '06: 45'], ['KYN', '08: 32', '08: 35'], ['PNVL', '09: 25', '09: 30']], '02432': [['NDLS', 'Null', '11:25'], ['KOTA', '16:00', '16:10'], ['BRC', '22:50', '23:08'], ['PNVL', '05:00', '05:05'], ['MAO', '13:02', '13:12'], ['MAJN', '18:25', '18:35'], ['CLT', '21:52', '21:55'], ['ERS', '01:40', '01:45'], ['TVC', '05:25', 'Null']], '02284': [['NDLS', 'Null', '21:35'], ['KOTA', '02:55', '03:05'], ['RTM', '07:05', '07:10'], ['BRC', '11:01', '11:10'], ['BSR', '16:20', '16:25'], ['PNVL', '17:55', '18:00'], ['RN', '23:20', '23:25'], ['MAO', '04:25', '04:35'], ['MAJN', '10:15', '10:25'], ['CLT', '13:27', '13:30'], ['ERS', '18:20', 'Null']], '20926': [['KLK', 'Null', '10:20'], ['CDG', '11:05', '11:20'], ['UMB', '12:05', '13:10'], ['KKDE', '13:40', '13:42'], ['KUN', '14:04', '14:06'], ['PNP', '14:36', '14:38'], ['SNP', '15:16', '15:18'], ['SZM', '15:54', '15:56'], ['NDLS', '16:25', '16:45'], ['FDB', '17:11', '17:13'], ['MTJ', '19:10', '19:15'], ['BTE', '19:41', '19:43'], ['BXN', '20:11', '20:13'], ['HAN', '20:36', '20:38'], ['GGC', '21:13', '21:15'], ['SWM', '22:00', '22:05'], ['KOTA', '23:30', '23:40'], ['SGZ', '01:15', '01:17'], ['NAD', '03:13', '03:15'], ['RTM', '04:15', '04:25'], ['MGN', '05:28', '05:30'], ['DHD', '05:57', '05:59'], ['GDA', '07:20', '07:22'], ['BRC', '08:20', '08:30'], ['BH', '09:16', '09:18'], ['ST', '10:23', '10:28'], ['NVS', '10:49', '10:51'], ['BL', '\t11:28', '11:30'], ['VAPI', '11:50', '11:52'], ['DRD', '12:32', '12:34'], ['BVI', '\t13:55', '13:57'], ['ADH', '14:17', '14:19'], ['BDTS', '14:45', 'Null']], '02926': [['KLK', 'Null', '10:20'], ['CDG', '11:05', '11:20'], ['UMB', '12:05', '13:10'], ['KKDE', '13:40', '13:42'], ['KUN', '14:04', '14:06'], ['PNP', '14:36', '14:38'], ['SNP', '15:16', '15:18'], ['SZM', '15:54', '15:56'], ['NDLS', '16:25', '16:45'], ['FDB', '17:11', '17:13'], ['MTJ', '19:10', '19:15'], ['BTE', '19:41', '19:43'], ['BXN', '20:11', '20:13'], ['HAN', '20:36', '20:38'], ['GGC', '21:13', '21:15'], ['SWM', '22:00', '22:05'], ['KOTA', '23:30', '23:40'], ['SGZ', '01:15', '01:17'], ['NAD', '03:13', '03:15'], ['RTM', '04:15', '04:25'], ['MGN', '05:28', '05:30'], ['DHD', '05:57', '05:59'], ['GDA', '07:20', '07:22'], ['BRC', '08:20', '08:30'], ['BH', '09:16', '09:18'], ['ST', '10:23', '10:28'], ['NVS', '10:49', '10:51'], ['BL', '\t11:28', '11:30'], ['VAPI', '11:50', '11:52'], ['DRD', '12:32', '12:34'], ['BVI', '\t13:55', '13:57'], ['ADH', '14:17', '14:19'], ['BDTS', '14:45', 'Null']]}
# Out:
# {'20926', '02618', '02904', '02926', '02432', '02284', '02952'}

# %%
junction=['UDN', 'WR', 'JNU', 'CPR', 'LDH', 'VBL', 'BSP', 'HRR', 'PRR', 'JM', 'NMZ', 'TEL', 'ANND', 'SRR', 'GDR', 'KRPU', 'GAYA', 'KNW', 'RNY', 'AJNI', 'PLO', 'UBL', 'GNT', 'DD', 'MXN', 'HRS', 'BH', 'AH', 'ASK', 'CAR', 'MRJ', 'JSME', 'ED', 'BTT', 'BSL', 'MKP', 'VAPI', 'GD', 'R', 'SA', 'ST', 'SGL', 'GDA', 'AWR', 'APR', 'ABP', 'DHN', 'RPJ', 'PNP', 'LMG', 'ALJN', 'BVI', 'PUNE', 'RGDA', 'CPH', 'MTJ', 'AK', 'KZJ', 'HPU', 'ARJ', 'BD', 'GY', 'KOTA', 'MAU', 'TPZ', 'SHG', 'VKB', 'RRB', 'MVJ', 'DNA', 'GJL', 'G', 'KGG', 'PC', 'MKN', 'BE', 'KIR', 'JNH', 'LD', 'ASR', 'MNE', 'MUR', 'DLI', 'SEE', 'KRR', 'PAU', 'BUW', 'BKI', 'JL', 'GTL', 'FL', 'BJU', 'DKJ', 'MJ', 'RTM', 'PBN', 'ON', 'KIUL', 'LJN', 'ROK', 'NAD', 'DRD', 'HJP', 'SIR', 'WADI', 'BSB', 'MMR', 'AII', 'FD', 'LKO', 'BOE', 'PHR', 'ADH', 'IAA', 'LWR', 'BRC', 'MKA', 'CNI', 'HWH', 'RXL', 'SV', 'BNW', 'NDKD', 'NYN', 'PNBE', 'LUNI', 'RGS', 'SKI', 'SGUJ', 'JU', 'BDTS', 'ND', 'JP', 'CTC', 'SLO', 'SWM', 'MDP', 'MAO', 'PGW', 'NWP', 'RE']

trn_sch2={}
for i in trn_sch:
    trn_sch2[i]={}
    for j in trn_sch[i]:
        trn_sch2[i][j[0]]=[j[1],j[2]]
print(trn_sch2)
# Out:
# {'09040': {'MFP': ['06:00:00', '06:00:00'], 'MTR': ['06:23:00', '06:25:00'], 'MAI': ['06:36:00', '06:38:00'], 'CAA': ['06:47:00', '06:49:00'], 'BMKI': ['07:23:00', '07:28:00'], 'SGL': ['08:03:00', '08:05:00'], 'BTH': ['08:23:00', '08:28:00'], 'NKE': ['09:00:00', '09:05:00'], 'HIR': ['09:19:00', '09:21:00'], 'BUG': ['09:47:00', '09:52:00'], 'PNYA': ['10:48:00', '10:50:00'], 'KZA': ['10:59:00', '11:01:00'], 'SBZ': ['11:15:00', '11:17:00'], 'CPJ': ['11:41:00', '11:46:00'], 'PPC': ['12:17:00', '12:19:00'], 'GKP': ['13:05:00', '13:20:00'], 'SWA': ['13:48:00', '13:50:00'], 'MHH': ['14:00:00', '14:02:00'], 'KLD': ['14:12:00', '14:14:00'], 'BST': ['14:40:00', '14:43:00'], 'BV': ['15:13:00', '15:15:00'], 'SNC': ['15:28:00', '15:30:00'], 'MSW': ['15:38:00', '15:40:00'], 'MUR': ['15:54:00', '15:56:00'], 'GD': ['16:20:00', '16:35:00'], 'CLJ': ['16:58:00', '17:00:00'], 'JLD': ['17:21:00', '17:23:00'], 'BUW': ['17:41:00', '17:43:00'], 'BBK': ['18:18:00', '18:23:00'], 'GTNR': ['19:04:00', '19:06:00'], 'BNZ': ['19:18:00', '19:20:00'], 'LC': ['19:41:00', '19:43:00'], 'LJN': ['20:20:00', '20:55:00'], 'ON': ['21:49:00', '21:50:00'], 'CNB': ['22:30:00', '22:37:00'], 'PHD': ['23:40:00', '23:42:00'], 'BNT': ['00:22:00', '00:24:00'], 'ETW': ['00:46:00', '00:48:00'], 'SKB': ['01:27:00', '01:29:00'], 'FZD': ['02:01:00', '02:03:00'], 'TDL': ['02:55:00', '03:00:00'], 'AF': ['04:00:00', '04:10:00'], 'IDH': ['04:22:00', '04:24:00'], 'KLB': ['04:53:00', '04:55:00'], 'FTS': ['05:16:00', '05:18:00'], 'RBS': ['05:32:00', '05:34:00'], 'BXN': ['07:00:00', '07:05:00'], 'HAN': ['07:26:00', '07:28:00'], 'SMBJ': ['07:37:00', '07:39:00'], 'GGC': ['08:05:00', '08:10:00'], 'SWM': ['09:00:00', '09:05:00'], 'IDG': ['09:30:00', '09:32:00'], 'LKE': ['09:43:00', '09:45:00'], 'KOTA': ['10:45:00', '10:50:00'], 'DKNT': ['11:05:00', '11:07:00'], 'MKX': ['11:48:00', '11:50:00'], 'RMA': ['12:00:00', '12:02:00'], 'JHW': ['12:14:00', '12:16:00'], 'BWM': ['12:30:00', '12:32:00'], 'GOH': ['12:50:00', '12:52:00'], 'SGZ': ['13:00:00', '13:05:00'], 'SVA': ['13:20:00', '13:22:00'], 'CMU': ['13:38:00', '13:40:00'], 'VMA': ['14:23:00', '14:25:00'], 'MEP': ['14:53:00', '14:55:00'], 'NAD': ['15:45:00', '15:47:00'], 'KUH': ['15:58:00', '16:00:00'], 'RTM': ['16:35:00', '16:45:00'], 'BMI': ['17:21:00', '17:23:00'], 'MGN': ['17:53:00', '17:55:00'], 'DHD': ['18:19:00', '18:21:00'], 'GDA': ['19:40:00', '19:42:00'], 'DRL': ['20:00:00', '20:01:00'], 'BRC': ['20:47:00', '20:57:00'], 'AKV': ['22:04:00', '22:05:00'], 'ST': ['23:20:00', '23:25:00'], 'BL': ['00:35:00', '00:37:00'], 'VAPI': ['00:57:00', '00:59:00'], 'BOR': ['02:08:00', '02:10:00'], 'BVI': ['03:35:00', '03:40:00'], 'ADH': ['04:02:00', '04:04:00'], 'BDTS': ['04:35:00', '04:35:00']}, '02419': {'LKO': ['06:00:00', '06:00:00'], 'ON': ['06:56:00', '06:58:00'], 'CNB': ['07:35:00', '07:40:00'], 'PNK': ['07:56:00', '07:58:00'], 'RURA': ['08:22:00', '08:24:00'], 'JJK': ['08:40:00', '08:42:00'], 'PHD': ['09:04:00', '09:06:00'], 'ETW': ['09:46:00', '09:48:00'], 'SKB': ['10:24:00', '10:26:00'], 'FZD': ['10:43:00', '10:45:00'], 'TDL': ['11:18:00', '11:21:00'], 'HRS': ['11:55:00', '11:57:00'], 'ALJN': ['12:21:00', '12:23:00'], 'KRJ': ['12:53:00', '12:55:00'], 'GZB': ['14:12:00', '14:14:00'], 'NDLS': ['15:05:00', '15:05:00']}, '02296': {'DNR': ['20:10:00', '20:10:00'], 'ARA': ['20:38:00', '20:40:00'], 'BXR': ['21:23:00', '21:25:00'], 'MGS': ['23:14:00', '23:24:00'], 'MZP': ['00:25:00', '00:30:00'], 'ACOI': ['01:50:00', '02:00:00'], 'STA': ['05:00:00', '05:10:00'], 'MYR': ['05:33:00', '05:35:00'], 'KTE': ['06:25:00', '06:30:00'], 'JBP': ['08:00:00', '08:10:00'], 'NU': ['09:16:00', '09:18:00'], 'PPI': ['10:23:00', '10:25:00'], 'ET': ['12:35:00', '12:45:00'], 'GDYA': ['13:51:00', '13:53:00'], 'BZU': ['14:36:00', '14:39:00'], 'PAR': ['15:53:00', '15:55:00'], 'NGP': ['17:55:00', '18:10:00'], 'SEGM': ['19:02:00', '19:04:00'], 'CD': ['21:07:00', '21:10:00'], 'BPQ': ['22:00:00', '22:10:00'], 'SKZR': ['22:59:00', '23:00:00'], 'RDM': ['00:02:00', '00:03:00'], 'WL ...

# %%
print([i[0] for i in trn_sch["02904"]])
# Out:
# ['ASR', 'BEAS', 'JUC', 'JRC', 'PGW', 'LDH', 'UMB', 'YJUD', 'SRE', 'MOZ', 'MUT', 'MTC', 'GZB', 'NZM', 'FDB', 'MTJ', 'BTE', 'BXN', 'HAN', 'SMBJ', 'GGC', 'SWM', 'KOTA', 'BWM', 'SGZ', 'NAD', 'RTM', 'MGN', 'DHD', 'GDA', 'BRC', 'ST', 'BVI', 'DDR', 'BCT']

# %%
def stat_code(name,flag=0):
    url =" http://indianrailapi.com/api/v2/StationNameToCode/apikey/0fe3b963408929419d6d519b06fd4110/StationName/"+name+"/"
    response = requests.get(url)
    # print(response) successfully
    data=response.text
    # print(data[])
    parsed=json.loads(data)
    #print(json.dumps(parsed, indent=4))
    code=parsed['Station']['StationCode']
    if code==None:
        if flag==1:
            return "NOT WORKING"
        name=name.upper()+" "+"JN"
        flag=1
        return stat_code(name,flag)
    #print([code,name])
    return code

    # date=parsed['glossary']['title']
    #print(date)y

# %%
start=time.process_time()
train_number_stob=[]
from_station=input()
to_station=input()
code_sour=stat_code(from_station)
code_dest=stat_code(to_station)

def my(code_sour,code_dest):
    
    if code_sour=="NOT WORKING" or code_dest=="NOT WORKING":
        print("-----> Wrong Station <-----")
        return None
    url = "http://indianrailapi.com/api/v2/TrainBetweenStation/apikey/0fe3b963408929419d6d519b06fd4110/From/"+code_sour+"/To/"+code_dest+"/"
    response = requests.get(url)
    
    # print(response) successfully
    data=response.text
    if data[17:20]!='200':
        return None
    # print(data[])
    parsed=json.loads(data)
    #print(json.dumps(parsed, indent=4))
    date=parsed['Trains']
    #print(date)
    
    train_number=[]
    
    for i in date:
        train_number.append(i['TrainNo'])
    return train_number

    
print(time.process_time()-start)  
#print(from_station,to_station)
# Out:
# new delhi
# mumbai central
# 0.046875

# %%
train_number_stob=my(code_sour,code_dest)
train_number_stob=list(set(train_number_stob)-set(exception))
print(train_number_stob)
# Out:
# ['20926', '02618', '02904', '02926', '02432', '02284', '02952']

# %%
## all stations betwee source----> destination
station=[]
for i in train_number_stob:
    station.extend([j[0] for j in trn_sch[i]])
staion=list(set(station))
station=list(set(station)&set(junction))
print(station)
print(len(station))
# Out:
# ['BRC', 'BDTS', 'SRR', 'BSL', 'VAPI', 'KNW', 'PNP', 'ST', 'GDA', 'MMR', 'BVI', 'LDH', 'SIR', 'SWM', 'PGW', 'ADH', 'MAO', 'NAD', 'BH', 'ASR', 'KOTA', 'MTJ', 'DRD', 'RTM']
# 24

# %%
## intermediate trains
for i in station:
    inter=i
    print(inter,code_dest)
    train_inter_to_desti=my(inter,code_dest)
    if train_inter_to_desti==None:
        continue
    source_inter=list(set(train_inter_to_desti)&set(train_number_stob))
    train_inter_to_desti=list(set(train_inter_to_desti)-set(train_number_stob))
    train_inter_to_desti=list(set(train_inter_to_desti)-set(exception))
    if len(train_inter_to_desti)>0:
        end=[]
        start=[]
        for j in train_inter_to_desti:
            end.append(trn_sch2[j][inter][0])
        print("inter_to_desti",inter_to_desti)
        
        for j in source_inter:
            start.append(trn_sch2[j][inter][0])
        print("sourcetointer",source)
        print(end,start,sep="\n")
        for j in train_inter_to_desti:    
            print(f"from {inter} to {code_dest}----->{j}")
# Out:
# BRC BCT
# ['20:47:00', '06:40:00', '20:47:00', '05:35:00', '00:30:00', '01:39:00']
# ['08: 20', '22:53:00', '08:16:00', '22:18:00', '10:55:00', '03:24:00']
# from BRC to BCT----->09038
# from BRC to BCT----->02934
# from BRC to BCT----->09040
# from BRC to BCT----->02479
# from BRC to BCT----->09042
# from BRC to BCT----->02956
# BDTS BCT
# SRR BCT
# ['16:35:00', '15:20:00']
# []
# from SRR to BCT----->06346
# from SRR to BCT----->02617
# BSL BCT
# ['14:35:00', '18:50:00', '12:05:00', '11:45:00', '19:45:00', '19:10:00', '06:00:00', '21:05:00', '02:25:00', '07:30:00']
# ['01:55:00']
# from BSL to BCT----->01072
# from BSL to BCT----->01062
# from BSL to BCT----->02533
# from BSL to BCT----->05646
# from BSL to BCT----->02541
# from BSL to BCT----->01016
# from BSL to BCT----->01094
# from BSL to BCT----->02810
# from BSL to BCT----->03201
# from BSL to BCT----->02142
# VAPI BCT
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-151-6107aa868809> in <module>()
#      13         start=[]
#      14         for j in train_inter_to_desti:
# ---> 15             end.append(trn_sch2[j][inter][0])
#      16         for j in source_inter:
#      17             start.append(trn_sch2[j][inter][0])
#
# KeyError: 'VAPI'

# %%
def seat_availability(train_number_stob,source,desti):
    for i in train_number_stob:
        if 1 in seat[i]:
            station_name=[j[0] for j in trn_sch[i]]
            print(station_name)
            x=station_name.index(desti)
            if seat[i][x]==1:
                print(i+"---->"+source+"---->"+desti)
                continue
            else:

                temp=station_name[x-seat[i][x::-1].index(1)]
                print(temp)
                print(i+"---->"+source+"---->"+temp)
                source=temp
                continue

        else:
            continue

# %%
x={4,5,6}
y={4,5,6}
print(list(x-y))
# Out:
# []

# %%
trn_sch={'02952': [['NDLS', 'Null', '17:00'], ['KOTA', '21:40', '21:50'], ['RTM', '00:42', '00:45'], ['BRC', '03:48', '03:56'], ['ST', '05:28', '05:33'], ['BCT', '08:40', 'Null']], '02904': [['NDLS', 'Null', '07:20'], ['FDB', '07:37', '07:39'], ['MTJ', '09:45', '09:50'], ['BTE', '10:23', '10:25'], ['BXN', '10:53', '10:55'], ['HAN', '11:18', '11:20'], ['SMBJ', '11:28', '11:30'], ['GGC', '12:00', '12:05'], ['SWM', '12:50', '12:55'], ['KOTA', '14:15', '14:25'], ['RMA', '15:21', '15:22'], ['BWM', '15:43', '15:45'], ['SGZ', '16: 08', '16: 10'], ['NAD', '17:50', '17:52'], ['RTM', '18:50', '19:00'], ['MGN', '20:03', '20:05'], ['DHD', '20: 32','20: 34'], ['GDA', '21: 51', '21: 53'], ['BRC', '22: 53', '23: 03'], ['ST', '00: 57', '01: 02'], ['BVI', '03: 58', '04: 02'], ['DDR', '04:41', '04:44'], ['BCT', '05:05', 'Null']], '02414': [['NDLS', 'Null', '11:25'], ['KOTA', '16:00', '16:10'], ['BRC', '22:50', '23:08'], ['ST', '00:43', '00:46'], ['PNVL', '05:08', '05:13'], ['RN', '09:30', '09:35'], ['MAO', '12:50', 'Null']], '02618': [['NDLS', 'Null', '09:15'], ['FDB', '09: 35', '09: 37'], ['MTJ', '11: 03', '11: 05'], ['AGC', '11: 50', '11: 55'], ['MRA', '13: 22', '13: 24'], ['GWL', '13: 55', '14: 00'], ['JHS', '15: 30', '15: 40'], ['BINA', '17: 40', '17: 45'], ['BPL', '19:40', '19:50'], ['ET', '21:25', '21:30'], ['KNW', '23;37', '23:40'], ['BAU', '00:30', '00:32'], ['BSL', '01:30', '01:35'], ['MMR', '04: 23', '04: 25'], ['NK', '\t05: 15', '05: 20'], ['IGP', '06: 40', '06: 45'], ['KYN', '08: 32', '08: 35'], ['PNVL', '09: 25', '09: 30']], '02432': [['NDLS', 'Null', '11:25'], ['KOTA', '16:00', '16:10'], ['BRC', '22:50', '23:08'], ['PNVL', '05:00', '05:05'], ['MAO', '13:02', '13:12'], ['MAJN', '18:25', '18:35'], ['CLT', '21:52', '21:55'], ['ERS', '01:40', '01:45'], ['TVC', '05:25', 'Null']], '02284': [['NDLS', 'Null', '21:35'], ['KOTA', '02:55', '03:05'], ['RTM', '07:05', '07:10'], ['BRC', '11:01', '11:10'], ['BSR', '16:20', '16:25'], ['PNVL', '17:55', '18:00'], ['RN', '23:20', '23:25'], ['MAO', '04:25', '04:35'], ['MAJN', '10:15', '10:25'], ['CLT', '13:27', '13:30'], ['ERS', '18:20', 'Null']], '20926': [['KLK', 'Null', '10:20'], ['CDG', '11:05', '11:20'], ['UMB', '12:05', '13:10'], ['KKDE', '13:40', '13:42'], ['KUN', '14:04', '14:06'], ['PNP', '14:36', '14:38'], ['SNP', '15:16', '15:18'], ['SZM', '15:54', '15:56'], ['NDLS', '16:25', '16:45'], ['FDB', '17:11', '17:13'], ['MTJ', '19:10', '19:15'], ['BTE', '19:41', '19:43'], ['BXN', '20:11', '20:13'], ['HAN', '20:36', '20:38'], ['GGC', '21:13', '21:15'], ['SWM', '22:00', '22:05'], ['KOTA', '23:30', '23:40'], ['SGZ', '01:15', '01:17'], ['NAD', '03:13', '03:15'], ['RTM', '04:15', '04:25'], ['MGN', '05:28', '05:30'], ['DHD', '05:57', '05:59'], ['GDA', '07:20', '07:22'], ['BRC', '08:20', '08:30'], ['BH', '09:16', '09:18'], ['ST', '10:23', '10:28'], ['NVS', '10:49', '10:51'], ['BL', '\t11:28', '11:30'], ['VAPI', '11:50', '11:52'], ['DRD', '12:32', '12:34'], ['BVI', '\t13:55', '13:57'], ['ADH', '14:17', '14:19'], ['BDTS', '14:45', 'Null']], '02926': [['KLK', 'Null', '10:20'], ['CDG', '11:05', '11:20'], ['UMB', '12:05', '13:10'], ['KKDE', '13:40', '13:42'], ['KUN', '14:04', '14:06'], ['PNP', '14:36', '14:38'], ['SNP', '15:16', '15:18'], ['SZM', '15:54', '15:56'], ['NDLS', '16:25', '16:45'], ['FDB', '17:11', '17:13'], ['MTJ', '19:10', '19:15'], ['BTE', '19:41', '19:43'], ['BXN', '20:11', '20:13'], ['HAN', '20:36', '20:38'], ['GGC', '21:13', '21:15'], ['SWM', '22:00', '22:05'], ['KOTA', '23:30', '23:40'], ['SGZ', '01:15', '01:17'], ['NAD', '03:13', '03:15'], ['RTM', '04:15', '04:25'], ['MGN', '05:28', '05:30'], ['DHD', '05:57', '05:59'], ['GDA', '07:20', '07:22'], ['BRC', '08:20', '08:30'], ['BH', '09:16', '09:18'], ['ST', '10:23', '10:28'], ['NVS', '10:49', '10:51'], ['BL', '\t11:28', '11:30'], ['VAPI', '11:50', '11:52'], ['DRD', '12:32', '12:34'], ['BVI', '\t13:55', '13:57'], ['ADH', '14:17', '14:19'], ['BDTS', '14:45', 'Null']]}

# %%
trn_sch2={}
for i in trn_sch:
    trn_sch2[i]={}
    for j in trn_sch[i]:
        trn_sch2[i][j[0]]=[j[1],j[2]]
        
print(trn_sch2['02952']['KOTA'])
# Out:
# ['21:40', '21:50']

# %%
{
    "ResponseCode": "201",
    "Status": "FAILED",
    "TotalTrains": null,
    "Trains": null,
    "Message": null
}

# %%
# Python program to read 
# json file 
  
  
import json 
  
# Opening JSON file 
f = open('ALL_Train_Schedule.json',) 
  
# returns JSON object as  
# a dictionary 
schedule = json.load(f)
