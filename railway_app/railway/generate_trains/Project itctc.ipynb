# %%
data={'Adipur Junction':['Bhuj','Gandhidham Junction'],
      'Ahmedabad Junction':['Nadiad Junction','Sabarmati Junction','Viramgam Junction'],
      'Anand Junction':['Nadiad Junction','Petlad Junction','Godhra Junction','Vasad Junction'],
      'Ankleshwar Junction':['Bharuch Junction','Surat'],
      'Bharuch Junction':['Ankleshwar Junction','Vadodara Junction'],
      'Bhavnagar Terminus':['Dhola Junction',],
      'Bhildi Junction':['Palanpur Junction','Mahesana Junction','Samakhiali Junction'],
      'Bhuj':['Gandhidham Junction',],
      'Botad Junction':['Surendranagar Junction','Dhola Junction',],
      'Dhasa Junction':['Dhola Junction','Mahuva Junction',],
      'Dhola Junction':['Botad Junction','Dhasa Junction','Bhavnagar Terminus'],
      'Dhrangadhra Junction':['Surendranagar Junction','Viramgam Junction','Maliya Miyana Junction'],
      'Gandhidham Junction':['Bhuj','Samakhiali Junction'],
      'Godhra Junction':['Anand Junction','Vadodara Junction'],
      'Jetalsar Junction':['Kanalus Junction','Porbandar','Junagadh Junction','Rajkot Junction'],
      'Junagadh Junction':['Jetalsar Junction','Veraval Junction',],
      'Kalol Junction':['Sabarmati Junction','Mahesana Junction'],
      'Kanalus Junction':['Okha','Rajkot Junction','Porbandar','Jetalsar Junction'],
      'Mahesana Junction':['Bhildi Junction','Palanpur Junction','Kalol Junction'],
      'Mahuva Junction':['Dhasa Junction',],
      'Maliya Miyana Junction':['Samakhiali Junction','Dhrangadhra Junction','Wankaner Junction'],
      'Nadiad Junction':['Ahmedabad Junction','Anand Junction','Petlad Junction'],
      'Okha':['Kanalus Junction'],
      'Palanpur Junction':['Bhildi Junction','Abu road','Mahesana Junction'],
      'Petlad Junction':['Vasad Junction','Nadiad Junction','Anand Junction','Tarapur Junction'],
      'Porbandar':['Kanalus Junction','Jetalsar Junction',],
      'Rajkot Junction':['Wankaner Junction','Kanalus Junction','Jetalsar Junction'],
      'Sabarmati Junction':['Ahmedabad Junction','Kalol Junction','Viramgam Junction'],
      'Samakhiali Junction':['Bhildi Junction','Gandhidham Junction','Maliya Miyana Junction',],
      'Surat':['Ankleshwar Junction','Valsad'],
      'Surendranagar Junction':['Dhrangadhra Junction','Viramgam Junction','Wankaner Junction','Botad Junction'],
      'Tarapur Junction':['Petlad Junction'],
      'Vadodara Junction':['Godhra Junction','Vasad Junction','Samlaya Junction','Bharuch Junction'],
      'Vasad Junction':['Anand Junction','Vadodara Junction','Petlad Junction'],
      'Valsad':['Surat','Vapi'],
      'Vapi':['Valsad',],
      'Veraval Junction':['Junagadh Junction',],
      'Viramgam Junction':['Ahmedabad Junction','Sabarmati Junction','Mahesana Junction','Dhrangadhra Junction','Surendranagar Junction',],
      'Wankaner Junction':['Surendranagar Junction','Maliya Miyana Junction','Rajkot Junction',],
     }

# %%
final_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-4fb078031bd0> in <module>
# ----> 1 final_1
#
# NameError: name 'final_1' is not defined

# %%
'':[''],

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url="https://en.wikipedia.org/wiki/Category:Railway_junction_stations_in_Gujarat"

# %%
page = urllib.request.urlopen(url)

# %%
soap = BeautifulSoup(page, "lxml")

# %%
print(soap.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Category:Railway junction stations in Gujarat - Wikipedia
#   </title>
#   <script>
# ...

# %%
# Out:
# <title>Category:Railway junction stations in Gujarat - Wikipedia</title>

# %%
all_title=soap.find_all("div",class_="mw-category-group")

# %%
print(all_title[0])
# Out:
# <div class="mw-category-group"><h3>A</h3>
# <ul><li><a href="/wiki/Adipur_Junction_railway_station" title="Adipur Junction railway station">Adipur Junction railway station</a></li>
# <li><a href="/wiki/Ahmedabad_Junction_railway_station" title="Ahmedabad Junction railway station">Ahmedabad Junction railway station</a></li>
# <li><a href="/wiki/Ambliyasan_Junction_railway_station" title="Ambliyasan Junction railway station">Ambliyasan Junction railway station</a></li>
# <li><a href="/wiki/Anand_Junction_railway_station" title="Anand Junction railway station">Anand Junction railway station</a></li>
# <li><a href="/wiki/Ankleshwar_Junction_railway_station" title="Ankleshwar Junction railway station">Ankleshwar Junction railway station</a></li>
# <li><a href="/wiki/Asarva_Junction_railway_station" title="Asarva Junction railway station">Asarva Junction railway station</a></li></ul></div>

# %%
new_list=all_title[0].findAll('a')
print(new_list[1].text)
final=[]
# Out:
# Ahmedabad Junction railway station

# %%
for i in all_title:
    temp=i.findAll('a')
    for j in temp:
        final.append(j.text)

# %%
new_final=[i[-16::-1] for i in final]

# %%
final_1=[i[-1:0:-1] for i in new_final]

# %%
final_1
# Out:
# ['Adipur Junction',
#  'Ahmedabad Junction',
#  'Ambliyasan Junction',
#  'Anand Junction',
#  'Ankleshwar Junction',
#  'Asarva Junction',
#  'Bharuch Junction',
#  'Bhildi Junction',
#  'Bilimora Junction',
#  'Bochasan Junction',
#  'Botad Junction',
#  'Dahinsara Junction',
#  'Dhari Junction',
#  'Dhasa Junction',
#  'Dhola Junction',
#  'Dhrangadhra Junction',
#  'Dungar Junction',
#  'Gandhidham Junction',
#  'Godhra Junction',
#  'Jam Jodhpur Junction',
#  'Jetalsar Junction',
#  'Jorawarnagar Junction',
#  'Junagadh Junction',
#  'Kalol Junction',
#  'Kanalus Junction',
#  'Kanjari Boriyavi Junction',
#  'Katkola Junction',
#  'Kosamba Junction',
#  'Mahesana Junction',
#  'Mahuva Junction',
#  'Maliya Miyana Junction',
#  'Miyagam Karjan Junction',
#  'Nadiad Junction',
#  'Palanpur Junction',
#  'Petlad Junction',
#  'Prachi Road Junction',
#  'Rajkot Junction',
#  'Rajula Junction',
#  'Ranuj Junction',
#  'Sabarmati Junction',
#  'Samakhiali Junction',
# ...

# %%
Junction={"Ajmer Junction":['Chittorgarh Junction','Phulera Junction','Marwar Junction'],
          "Alwar Junction":['Bandikui Junction',],
          "Bharatpur Junction":['Bayana Junction','Bandikui Junction','Kota Junction'],
          "Bikaner Junction":['Merta Road Junction','Phalodi Junction','Churu Junction','Ratangarh Junction'],
          "Chittorgarh Junction":['Kota Junction','Mavli Junction','Ajmer Junction'],
          "Churu Junction":['Sadulpur Junction', 'Ratangarh Junction','Sikar Junction','Bikaner Junction'],
          "Jaipur Junction":['Phulera Junction','Bandikui Junction','Ringas Junction','Ajmer Junction','Sawai Madhopur Junction'],
          "Jodhpur Junction":['Luni Junction','Phalodi Junction', 'Pipar Road Junction'],
          "Kota Junction":['Ramganj Mandi Junction','Sawai Madhopur Junction','Chittorgarh Junction'],
          "Sikar Junction":['Ringas Junction','Churu Junction','Phulera Junction','Makrana Junction','Loharu Junction'],
          "Sri Ganganagar Junction":['Suratgarh Junction','Hanumangarh Junction'],
          "Phulera Junction":['Jaipur Junction','Makrana Junction','Ajmer Junction','Ringas Junction'],
          "Bandikui Junction":['Jaipur Junction','Alwar Junction','Bharatpur Junction'],
          "Samdari Junction":["Jodhpur Junction",'Luni Junction','Marwar Junction'],
          "Bayana Junction":['Bharatpur Junction','Sawai Madhopur Junction','Kota Junction'],
          "Makrana Junction":['Phulera Junction','Degana Junction','Merta Road Junction'],
          "Merta Road Junction":['Degana Junction','Bikaner Junction','Pipar Road Junction'],
          "Hanumangarh Junction":['Sri Ganganagar Junction','Suratgarh Junction','Sadulpur Junction'],
          "Pipar Road Junction":['Jodhpur Junction','Merta Road Junction','Luni Junction'],
          "Luni Junction":['Samdari Junction','Jodhpur Junction','Marwar Junction'],
          "Marwar Junction":['Luni Junction','Ajmer Junction','Abu road',],
          "Ratangarh Junction":['Degana Junction','Churu Junction','Bikaner Junction'],
          "Sawai Madhopur Junction":['Kota Junction','Bayana Junction','Jaipur Junction'],
          'Degana Junction':['Merta Road Junction',"Makrana Junction","Ratangarh Junction",],
          'Loharu Junction':['Sadulpur Junction',"Sikar Junction",],
          'Mavli Junction':['Udaipur City','Chittorgarh Junction',],
          'Phalodi Junction':["Jodhpur Junction",'Bikaner Junction',],
          'Ramganj Mandi Junction':['Kota Junction',],
          'Ringas Junction':['Jaipur Junction','Phulera Junction','Sikar Junction',],
          'Sadulpur Junction':["Hanumangarh Junction",'Loharu Junction',"Churu Junction",],
          'Sri Ganganagar':['Hanumangarh Junction','Suratgarh Junction',],
          'Suratgarh Junction':['Sri Ganganagar','Bikaner Junction','Hanumangarh Junction',],
          'Udaipur City':['Mavli Junction',],
          'Abu road':['Palanpur Junction','Marwar Junction',]
         
         
         }

# %%
li=[i for i in Junction]

# %%
li2=[j for j in Junction.values()]
li3=[]

# %%
for i in li2:
    for j in i:
        li3.append(j)

# %%
li3=set(li3)
li1=set(li)

# %%
li3-li1
# Out:
# {'Degana Junction',
#  'Khwaja Garib Nawaz Madar Junction',
#  'Lalgarh Junction',
#  'Lohar Junction',
#  'Mavli Junction',
#  'Mohari Junction',
#  'Phalodi Junction',
#  'Raikabag Palace Junction',
#  'Ramganj Mandi Junction',
#  'Ringas Junction',
#  'Sadulpur Junction',
#  'Sadulpur Junction ',
#  'Sarupsar Junction',
#  'Sri Ganganagar',
#  'Suratgarh Junction'}

# %%
import json

# %%
with open('neighbour_stat.json','w') as outfile:
    json.dump(data,outfile)

# %%
with open('neighbour_stat_guj.json') as outfile:
    new_dict=json.load(outfile)

# %%
comb_data=data.update(Junction)

# %%
with open('neighbour_stat.json') as outfile:
    new_dict=json.load(outfile)

# %%
len(new_dict.keys())
# Out:
# 73

# %%
# Out:
# ['Palanpur Junction', 'Marwar Junction']

# %%
len(data.keys())
# Out:
# 73
